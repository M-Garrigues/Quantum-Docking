# %%
from rdkit import Chem

# %%
m = Chem.MolFromPDBFile("../data/receptors/1AO2.pdb")
m

# %%
from rdkit.Chem import Draw

img = Draw.MolToImage(m)
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=300x300>

# %%
m = Chem.MolFromPDBFile("../data/ligands/H2O2.pdb")
img = Draw.MolToImage(m)
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=300x300>

# %%
Donor_feat = factory.GetFeaturesForMol(m, includeOnly="Donor")

# %%
from pmapper.pharmacophore import Pharmacophore as P
from rdkit import Chem
from rdkit.Chem import AllChem
from pprint import pprint

# load a molecule from SMILES and generate 3D coordinates
mol = Chem.MolFromPDBFile("../data/ligands/H2O2.pdb")
mol = Chem.AddHs(mol)
AllChem.EmbedMolecule(mol, randomSeed=42)

# create pharmacophore
p = P()
p.load_from_mol(mol)

# %%
pprint(p.get_graph())

# %%
import networkx as nx
import matplotlib.pyplot as plt
g1 = p.get_graph()
nx.draw(g1)
plt.show()

# %%
p.get_descriptors()
# Out:
# {'AA1D0D1|AA1D0D1|DA0A1D1|DA0A1D1|0|0|1': 1}
